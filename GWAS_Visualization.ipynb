# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 3.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 45.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 48.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 9.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.4 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gwaslab==3.4.43
# Out:
# ERROR: Ignored the following versions that require a different python version: 3.4.25 Requires-Python <=3.9,>=3.8; 3.4.26 Requires-Python <=3.9,>=3.8; 3.4.27 Requires-Python <=3.9,>=3.8; 3.4.28 Requires-Python <=3.9,>=3.8; 3.4.29 Requires-Python <=3.9,>=3.8; 3.4.30 Requires-Python <=3.10,>=3.8; 3.4.31 Requires-Python <=3.10,>=3.8; 3.4.32 Requires-Python <=3.10,>=3.8; 3.4.33 Requires-Python <=3.10,>=3.8; 3.4.34 Requires-Python <=3.10,>=3.8; 3.4.35 Requires-Python <=3.10,>=3.8; 3.4.36 Requires-Python <=3.10,>=3.8; 3.4.37 Requires-Python <=3.10,>=3.9; 3.4.38 Requires-Python <=3.10,>=3.9; 3.4.39 Requires-Python <=3.10,>=3.9; 3.4.40 Requires-Python <=3.10,>=3.9; 3.4.41 Requires-Python <=3.10,>=3.9; 3.4.42 Requires-Python <=3.10,>=3.9; 3.4.43 Requires-Python <=3.10,>=3.9
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gwaslab as gl
# Out:
# /var/folders/hq/mt_9wjp90cx45qsgnk3d7qfc0000gq/T/ipykernel_98318/2297581145.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
imiss = pd.read_csv("plink_results.imiss",sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/hq/mt_9wjp90cx45qsgnk3d7qfc0000gq/T/ipykernel_94115/2584321632.py:1: SyntaxWarning: invalid escape sequence '\s'
#   imiss = pd.read_csv("plink_results.imiss",sep="\s+")

# %%
imiss.head()
# Out:
#        FID      IID MISS_PHENO  N_MISS   N_GENO    F_MISS
# 0  HG00403  HG00403          Y   10020  1235116  0.008113
# 1  HG00404  HG00404          Y    9192  1235116  0.007442
# 2  HG00406  HG00406          Y   15751  1235116  0.012750
# 3  HG00407  HG00407          Y   14653  1235116  0.011860
# 4  HG00409  HG00409          Y    5667  1235116  0.004588

# %%
imiss.shape
# Out:
# (504, 6)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hist(imiss["F_MISS"])
ax.set_xlabel("Sample missing rate")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
lmiss = pd.read_csv("plink_results.lmiss",sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/hq/mt_9wjp90cx45qsgnk3d7qfc0000gq/T/ipykernel_94115/1980778369.py:1: SyntaxWarning: invalid escape sequence '\s'
#   lmiss = pd.read_csv("plink_results.lmiss",sep="\s+")

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hist(lmiss["F_MISS"])
ax.set_xlabel("SNP missing rate")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
het = pd.read_csv("plink_results.het",sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/hq/mt_9wjp90cx45qsgnk3d7qfc0000gq/T/ipykernel_94115/735711355.py:1: SyntaxWarning: invalid escape sequence '\s'
#   het = pd.read_csv("plink_results.het",sep="\s+")

# %%
print(het.head())
print(het.shape)
# Out:
#        FID      IID  O(HOM)    E(HOM)   N(NM)         F
# 0  HG00403  HG00403  180222  179600.0  217363  0.016980
# 1  HG00404  HG00404  180127  179700.0  217553  0.010230
# 2  HG00406  HG00406  178891  178900.0  216533 -0.000114
# 3  HG00407  HG00407  178992  179000.0  216677 -0.000803
# 4  HG00409  HG00409  179918  180100.0  218045 -0.006049
# (504, 6)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hist(het["F"],bins=20)
ax.set_xlabel("F_het")
ax.set_ylabel("Count")

ax.axvline(0.1,c="red",linestyle="dashed")
ax.axvline(-0.1,c="red",linestyle="dashed")

# %%
pca = pd.read_table("plink_results_projected.sscore",sep="\t")
pca.head()
# Out:
#       #FID      IID  ALLELE_CT  NAMED_ALLELE_DOSAGE_SUM   PC1_AVG   PC2_AVG  \
# 0  HG00403  HG00403     390256                   390256 -0.002903  0.024865
# 1  HG00404  HG00404     390696                   390696  0.000141  0.027965
# 2  HG00406  HG00406     388524                   388524 -0.007074  0.031545
# 3  HG00407  HG00407     388808                   388808 -0.006840  0.025073
# 4  HG00409  HG00409     391646                   391646 -0.000399  0.029033
#
#     PC3_AVG   PC4_AVG   PC5_AVG   PC6_AVG   PC7_AVG   PC8_AVG   PC9_AVG  \
# 0  0.010041  0.009576 -0.006940 -0.002217 -0.008241 -0.001147  0.003342
# 1  0.025389 -0.005825  0.002749  0.006587 -0.011366  0.007785  0.015929
# 2 -0.004370 -0.001262  0.011493 -0.005396  0.006192  0.004531 -0.000872
# 3 -0.006527  0.006797  0.011601 -0.010246 -0.013977  0.006194  0.013818
# 4 -0.018935 -0.001360 -0.029045  0.009418  0.017188 -0.012993  0.025247
#
#    PC10_AVG
# 0 -0.004329
# 1 -0.017978
# 2  0.002238
# 3 -0.008300
# ...

# %%
ped = pd.read_table("integrated_call_samples_v3.20130502.ALL.panel",sep="\t")
ped.head()
# Out:
#     sample  pop super_pop  gender  Unnamed: 4  Unnamed: 5
# 0  HG00096  GBR       EUR    male         NaN         NaN
# 1  HG00097  GBR       EUR  female         NaN         NaN
# 2  HG00099  GBR       EUR  female         NaN         NaN
# 3  HG00100  GBR       EUR  female         NaN         NaN
# 4  HG00101  GBR       EUR    male         NaN         NaN

# %%
pcaped=pd.merge(pca,ped,right_on="sample",left_on="IID",how="inner")
pcaped
# Out:
#         #FID      IID  ALLELE_CT  NAMED_ALLELE_DOSAGE_SUM   PC1_AVG   PC2_AVG  \
# 0    HG00403  HG00403     390256                   390256 -0.002903  0.024865
# 1    HG00404  HG00404     390696                   390696  0.000141  0.027965
# 2    HG00406  HG00406     388524                   388524 -0.007074  0.031545
# 3    HG00407  HG00407     388808                   388808 -0.006840  0.025073
# 4    HG00409  HG00409     391646                   391646 -0.000399  0.029033
# ..       ...      ...        ...                      ...       ...       ...
# 495  NA19087  NA19087     390232                   390232  0.082261 -0.033163
# 496  NA19088  NA19088     391510                   391510  0.087183 -0.043433
# 497  NA19089  NA19089     391462                   391462  0.084082 -0.036118
# 498  NA19090  NA19090     392880                   392880  0.073580 -0.026163
# 499  NA19091  NA19091     389664                   389664  0.081632 -0.041455
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=pcaped,x="PC1_AVG",y="PC2_AVG",hue="pop",s=50)
# Out:
# <Axes: xlabel='PC1_AVG', ylabel='PC2_AVG'>

# %%
sumstats = gl.Sumstats("1kgeas.B1.glm.firth",fmt="plink2")
# Out:
# 2024/04/16 14:17:09 GWASLab v3.4.40 https://cloufield.github.io/gwaslab/
# 2024/04/16 14:17:09 (C) 2022-2024, Yunye He, Kamatani Lab, MIT License, gwaslab@gmail.com
# 2024/04/16 14:17:09 Start to load format from formatbook....
# 2024/04/16 14:17:09  -plink2 format meta info:
# 2024/04/16 14:17:09   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2024/04/16 14:17:09   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2024/04/16 14:17:09   - format_version  : Alpha 3.3 final (3 Jun)
# 2024/04/16 14:17:09   - last_check_date  :  20220806
# 2024/04/16 14:17:09  -plink2 to gwaslab format dictionary:
# 2024/04/16 14:17:09   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2024/04/16 14:17:09   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2024/04/16 14:17:09 Start to initialize gl.Sumstats from file :1kgeas.B1.glm.firth
# ...

# %%
sumstats.data
# Out:
#                    SNPID  CHR       POS EA NEA       EAF        SE         Z  \
# 0            1:15774:G:A    1     15774  A   G  0.028283       NaN       NaN
# 1            1:15777:A:G    1     15777  G   A  0.073737       NaN       NaN
# 2            1:57292:C:T    1     57292  T   C  0.104675  0.215278  0.447162
# 3            1:77874:G:A    1     77874  A   G  0.019153  0.462751  0.249272
# 4            1:87360:C:T    1     87360  T   C  0.023139       NaN       NaN
# ...                  ...  ...       ... ..  ..       ...       ...       ...
# 1128727  22:51217954:G:A   22  51217954  A   G  0.033199       NaN       NaN
# 1128728  22:51218377:G:C   22  51218377  C   G  0.033333  0.362212 -0.994410
# 1128729  22:51218615:T:A   22  51218615  A   T  0.033266  0.362476 -1.029180
# 1128730  22:51222100:G:T   22  51222100  T   G  0.039157       NaN       NaN
# 1128731  22:51239678:G:T   22  51239678  T   G  0.034137       NaN       NaN
#
# ...

# %%
sumstats.get_lead(sig_level=5e-8)
# Out:
# 2024/04/16 14:25:26 Start to extract lead variants...v3.4.40
# 2024/04/16 14:25:26  -Current Dataframe shape : 1128732 x 14 ; Memory usage: 106.06 MB
# 2024/04/16 14:25:26  -Processing 1128732 variants...
# 2024/04/16 14:25:26  -Significance threshold : 5e-08
# 2024/04/16 14:25:26  -Sliding window size: 500  kb
# 2024/04/16 14:25:27  -Using P for extracting lead variants...
# 2024/04/16 14:25:27  -Found 43 significant variants in total...
# 2024/04/16 14:25:27  -Identified 4 lead variants!
# 2024/04/16 14:25:27 Finished extracting lead variants.
#                    SNPID  CHR        POS EA NEA       EAF        SE        Z  \
# 54904    1:167562605:G:A    1  167562605  A   G  0.391481  0.159644  7.69466
# 113179    2:55513738:C:T    2   55513738  C   T  0.376008  0.153158 -7.96249
# 549726   7:134368632:T:G    7  134368632  G   T  0.138105  0.225524  6.89019
# 1088750  20:42758834:T:C   20   42758834  T   C  0.227273  0.184322 -7.76908
#
# ...

# %%
sumstats.plot_mqq(skip=2,anno=True)
# Out:
# 2024/04/16 14:25:46 Start to create MQQ plot...v3.4.40:
# 2024/04/16 14:25:46  -Genomic coordinates version: 99...
# 2024/04/16 14:25:46  #WARNING! Genomic coordinates version is unknown.
# 2024/04/16 14:25:46  -Genome-wide significance level to plot is set to 5e-08 ...
# 2024/04/16 14:25:46  -Raw input contains 1128732 variants...
# 2024/04/16 14:25:46  -MQQ plot layout mode is : mqq
# 2024/04/16 14:25:46 Finished loading specified columns from the sumstats.
# 2024/04/16 14:25:46 Start data conversion and sanity check:
# 2024/04/16 14:25:46  -Removed 0 variants with nan in CHR or POS column ...
# 2024/04/16 14:25:46  -Removed 0 variants with CHR <=0...
# 2024/04/16 14:25:46  -Removed 220792 variants with nan in P column ...
# 2024/04/16 14:25:46  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2024/04/16 14:25:46  -Sumstats P values are being converted to -log10(P)...
# ...

# %%
sumstats.basic_check()
# Out:
# 2024/04/16 14:26:07 Start to check SNPID/rsID...v3.4.40
# 2024/04/16 14:26:07  -Current Dataframe shape : 1128732 x 14 ; Memory usage: 106.06 MB
# 2024/04/16 14:26:07  -Checking SNPID data type...
# 2024/04/16 14:26:07  -Converting SNPID to pd.string data type...
# 2024/04/16 14:26:07  -Checking if SNPID is CHR:POS:NEA:EA...(separator: - ,: , _)
# 2024/04/16 14:26:09 Finished checking SNPID/rsID.
# 2024/04/16 14:26:09 Start to fix chromosome notation (CHR)...v3.4.40
# 2024/04/16 14:26:09  -Current Dataframe shape : 1128732 x 14 ; Memory usage: 106.06 MB
# 2024/04/16 14:26:09  -Checking CHR data type...
# 2024/04/16 14:26:10  -Variants with standardized chromosome notation: 1128732
# 2024/04/16 14:26:10  -All CHR are already fixed...
# 2024/04/16 14:26:11 Finished fixing chromosome notation (CHR).
# 2024/04/16 14:26:11 Start to fix basepair positions (POS)...v3.4.40
# 2024/04/16 14:26:11  -Current Dataframe shape : 1128732 x 14 ; Memory usage: 107.13 MB
# ...

# %%
sumstats.plot_mqq(mode="r",anno=True,region=(2,54513738,56513738),region_grid=True,build="38")
#2:55513738
# Out:
# 2024/04/16 14:29:22 Start to create MQQ plot...v3.4.40:
# 2024/04/16 14:29:22  -Genomic coordinates version: 38...
# 2024/04/16 14:29:22  -Genome-wide significance level to plot is set to 5e-08 ...
# 2024/04/16 14:29:22  -Raw input contains 907940 variants...
# 2024/04/16 14:29:22  -MQQ plot layout mode is : r
# 2024/04/16 14:29:22  -Region to plot : chr2:54513738-56513738.
# 2024/04/16 14:29:22  -Extract SNPs in region : chr2:54513738-56513738...
# 2024/04/16 14:29:22  -Extract SNPs in specified regions: 705
# 2024/04/16 14:29:22 Finished loading specified columns from the sumstats.
# 2024/04/16 14:29:22 Start data conversion and sanity check:
# 2024/04/16 14:29:22  -Removed 0 variants with nan in CHR or POS column ...
# 2024/04/16 14:29:22  -Removed 0 variants with CHR <=0...
# 2024/04/16 14:29:22  -Removed 0 variants with nan in P column ...
# 2024/04/16 14:29:22  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# ...

# %%
gl.download_ref("1kg_eas_hg19")
# Out:
# 2024/04/16 14:30:46 Start to download  1kg_eas_hg19  ...
# 2024/04/16 14:30:46  -Downloading to: /Users/reziw3/.gwaslab/EAS.ALL.split_norm_af.1kgp3v5.hg19.vcf.gz
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /opt/miniconda3/envs/gwaslab/lib/python3.9/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/miniconda3/envs/gwaslab/lib/python3.9/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
sumstats.plot_mqq(mode="r",anno=True,region=(2,54531536,56731536),region_grid=True,vcf_path=gl.get_path("1kg_eas_hg19"),build="19")
# Out:
# 2024/04/16 14:30:57 Config file not exists...
# 2024/04/16 14:30:57 Created new config file...
# 2024/04/16 14:30:57  -Creating an empty config file...
# 2024/04/16 14:30:57  -Config file path: /opt/miniconda3/envs/gwaslab/lib/python3.9/site-packages/gwaslab/data/config.json
# 2024/04/16 14:30:57 Start to create MQQ plot...v3.4.40:
# 2024/04/16 14:30:57  -Genomic coordinates version: 19...
# 2024/04/16 14:30:57  -Genome-wide significance level to plot is set to 5e-08 ...
# 2024/04/16 14:30:57  -Raw input contains 907940 variants...
# 2024/04/16 14:30:57  -MQQ plot layout mode is : r
# 2024/04/16 14:30:57  -Region to plot : chr2:54531536-56731536.
# 2024/04/16 14:30:57  -Checking prefix for chromosomes in vcf files...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ...
